# %% [markdown]
# #1. Create an empty list and add elements to the end of the list

# %%
a = []
a.append('10')
a.append('20')
a.append('30')
a.append("A")
a.append("B")
a.append("C")
print("Values of a:", a)
# Out:
# Values of a: ['10', '20', '30', 'A', 'B', 'C']

# %%
#2. Replace an element with another element at any index of the list.

# %%
str = "republic"
my_list = list(str)
my_list[3]="c"
my_list
# Out:
# ['r', 'e', 'p', 'c', 'b', 'l', 'i', 'c']

# %%
#3. Replace the elements in the indexed part of the list with others

# %%
new = [12,4,6,"bahar",[3,4,5]]
for i in new: 
    print(i,end= ' ')
new[1:3] = ["rustamova","b"]
new
# Out:
# 12 4 6 bahar [3, 4, 5]
# [12, 'rustamova', 'b', 'bahar', [3, 4, 5]]

# %%
#4. Add an element according to the index of the list

# %%
listim = ['Rustamova','Bahar','22','45']
listim.insert(2,'sjh')
listim.insert(0,'bsbg')
listim
# Out:
# ['bsbg', 'Rustamova', 'Bahar', 'sjh', '22', '45']

# %%
#5. Delete the element of list

# %%
my_list = ['7',7,"hello",5-4j,'a',"apple"]
my_list.remove('7')
my_list
# Out:
# [7, 'hello', (5-4j), 'a', 'apple']

# %%
#6. Delete the element of list according to index

# %%
del my_list[4]
my_list
# Out:
# [7, 'hello', (5-4j), 'a']

# %%
#7. Delete the last element of list

# %%
my_list.pop()
my_list
# Out:
# [7, 'hello', (5-4j)]

# %%
my_list.pop(-2)
my_list
# Out:
# [7, (5-4j)]

# %%
#8. Create Tuple

# %%
tuple = 10,15,20,25
tuple
# Out:
# (10, 15, 20, 25)

# %%
tuple1 = (7,14,[21,28],'hello',5-3j)
tuple1
# Out:
# (7, 14, [21, 28], 'hello', (5-3j))

# %%
#9. Print Tuple ve the type of tuple

# %%
print(tuple1,type(tuple1))
# Out:
# (7, 14, [21, 28], 'hello', (5-3j)) <class 'tuple'>

# %%
#10. Assign the tuple's elements to other given ones, Print it

# %%
tuple2 = ('bahar',7,8,[3,5,7])
a,b,c,d = tuple2
print('a=',a)
print('c=',c)
# Out:
# a= bahar
# c= 8

# %%
#11. Create another tuple and join it

# %%
live = (3,4,'1234')
tuple2 + live
# Out:
# ('bahar', 7, 8, [3, 5, 7], 3, 4, '1234')

# %%
#12. Count the elements in a tuple

# %%
tuple2.count([3,5,7])
# Out:
# 1

# %%
tuple2.count(3)
# Out:
# 0

# %%
#13. Create dictionary

# %%
bahar = {'element1':{'name':'Bahar','surname':'Rustamova'},
         'element2':{'region':'Goygol','country':'Azerbaijan'},
         'age':'22',
         'interest':'swimming'}
bahar
# Out:
# {'element1': {'name': 'Bahar', 'surname': 'Rustamova'},
#  'element2': {'region': 'Goygol', 'country': 'Azerbaijan'},
#  'age': '22',
#  'interest': 'swimming'}

# %%
#14. Print the element and keys of dictionary

# %%
bahar.keys()
# Out:
# dict_keys(['element1', 'element2', 'age', 'interest'])

# %%
bahar['element1'].keys()
# Out:
# dict_keys(['name', 'surname'])

# %%
bahar.values()
# Out:
# dict_values([{'name': 'Bahar', 'surname': 'Rustamova'}, {'region': 'Goygol', 'country': 'Azerbaijan'}, '22', 'swimming'])

# %%
bahar['element2'].values()
# Out:
# dict_values(['Goygol', 'Azerbaijan'])

# %%
bahar.items()
# Out:
# dict_items([('element1', {'name': 'Bahar', 'surname': 'Rustamova'}), ('element2', {'region': 'Goygol', 'country': 'Azerbaijan'}), ('age', '22'), ('interest', 'swimming')])

# %%
#15. Print the element according to any key

# %%
bahar = {'b':{'name':{'surname':'Rustamova'}}}
bahar
# Out:
# {'b': {'name': {'surname': 'Rustamova'}}}

# %%
bahar['b']['name'].values()
# Out:
# dict_values(['Rustamova'])

# %%
bahar['b'].values()
# Out:
# dict_values([{'surname': 'Rustamova'}])
